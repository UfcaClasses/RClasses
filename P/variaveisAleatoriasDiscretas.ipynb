# %%
#VARIÁVEIS ALEATÓRIAS DISCRETAS
#link for random generation https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.beta.html#numpy.random.Generator.beta
#link for probability distribution functions https://docs.scipy.org/doc/scipy-0.16.1/reference/stats.html
import pandas as pd
# !pip install scipy

# %%
#Uniforme Discreta
x = list(range(1, 7))#exemplo do dado, Omega_x = (1, 2, ...., 6)
# print(x)
Omega_x_card = len(x)
Px = [1/Omega_x_card]*Omega_x_card#probability mass function
# print(Px)
Rx = []
for x_i in x:
    Rx.append(1 - x_i/Omega_x_card)#reliability: P(X>x_i) = 1 - P(X<=x_i) 
# print(Rx)
def printDistributions(x, Px, Rx, distName):
    dic = {'x':x, 'P(x)':Px, 'R(x)': Rx}
    # print(dic)
    df = pd.DataFrame(data=dic)
    print("************* " + distName + " PROBABILITY DISTRIBUTIONS *************")
    print(df)
    df.plot.bar(x = 'x', y = 'P(x)')
    df.plot.bar(x = 'x', y = 'R(x)')
printDistributions(x, Px, Rx, "Discrete Uniform")
# Out:
# ************* Discrete Uniform PROBABILITY DISTRIBUTIONS *************
#    x      P(x)      R(x)
# 0  1  0.166667  0.833333
# 1  2  0.166667  0.666667
# 2  3  0.166667  0.500000
# 3  4  0.166667  0.333333
# 4  5  0.166667  0.166667
# 5  6  0.166667  0.000000

# %%
#Geométrica
from scipy.stats import geom
# import matplotlib.pyplot as plt
#fig, ax = plt.subplots(2, 1)
p = .5#probabilidade de sucesso em uma tentativa
x = list(range(1,21))
dist = geom(p)#Omega_X = {1, 2, 3, ...}
Px = dist.pmf(x)#probability mass function: P(X=x)
Rx = dist.sf(x)#Reliability/Survival function: P(X>x) = 1 - P(X<=x)
printDistributions(x, Px, Rx, "Geometric")
# Out:
# ************* Geometric PROBABILITY DISTRIBUTIONS *************
#      x          P(x)          R(x)
# 0    1  5.000000e-01  5.000000e-01
# 1    2  2.500000e-01  2.500000e-01
# 2    3  1.250000e-01  1.250000e-01
# 3    4  6.250000e-02  6.250000e-02
# 4    5  3.125000e-02  3.125000e-02
# 5    6  1.562500e-02  1.562500e-02
# 6    7  7.812500e-03  7.812500e-03
# 7    8  3.906250e-03  3.906250e-03
# 8    9  1.953125e-03  1.953125e-03
# 9   10  9.765625e-04  9.765625e-04
# 10  11  4.882812e-04  4.882812e-04
# 11  12  2.441406e-04  2.441406e-04
# 12  13  1.220703e-04  1.220703e-04
# 13  14  6.103516e-05  6.103516e-05
# 14  15  3.051758e-05  3.051758e-05
# 15  16  1.525879e-05  1.525879e-05
# 16  17  7.629395e-06  7.629395e-06
# 17  18  3.814697e-06  3.814697e-06
# 18  19  1.907349e-06  1.907349e-06
# 19  20  9.536743e-07  9.536743e-07

# %%
#Binomial
from scipy.stats import binom
p = .1#probabilidade de sucesso em uma tentativa
n = 20#tamanho amostral
x = list(range(0,(n+1)))
dist = binom(n, p)#Omega_X = {1, 2, 3, ...}
Px = dist.pmf(x)#probability mass function: P(X=x)
Rx = dist.sf(x)#Reliability/Survival function: P(X>x) = 1 - P(X<=x)
printDistributions(x, Px, Rx, "Binomial")
# choose(1e+100,30)
# Out:
# ************* Binomial PROBABILITY DISTRIBUTIONS *************
#      x          P(x)          R(x)
# 0    0  1.215767e-01  8.784233e-01
# 1    1  2.701703e-01  6.082530e-01
# 2    2  2.851798e-01  3.230732e-01
# 3    3  1.901199e-01  1.329533e-01
# 4    4  8.977883e-02  4.317450e-02
# 5    5  3.192136e-02  1.125313e-02
# 6    6  8.867045e-03  2.386089e-03
# 7    7  1.970454e-03  4.156350e-04
# 8    8  3.557765e-04  5.985853e-05
# 9    9  5.270763e-05  7.150904e-06
# 10  10  6.442043e-06  7.088606e-07
# 11  11  6.507115e-07  5.814918e-08
# 12  12  5.422595e-08  3.923225e-09
# 13  13  3.707758e-09  2.154678e-10
# 14  14  2.059865e-10  9.481304e-12
# 15  15  9.154957e-12  3.263468e-13
# 16  16  3.178805e-13  8.466310e-15
# 17  17  8.310600e-15  1.557100e-16
# 18  18  1.539000e-16  1.810000e-18
# 19  19  1.800000e-18  1.000000e-20
# 20  20  1.000000e-20  0.000000e+00

# %%
#Hipergeométrica
from scipy.stats import hypergeom
N=20#tamanho da população (M in Python)
K=8#nº de sucessos na população (n in Python)
print("Probability success in one attempt = " + str(K/N))
n=6#tamanho da amostra (N in Python)
x = list(range(0,(min(n, K)+1)))#Omega_X
dist = hypergeom(M = N, n = K, N = n)#Omega_X = {0, 1, ..., min(n, K)}
Px = dist.pmf(x)#probability mass function: P(X=x)
Rx = dist.sf(x)#Reliability/Survival function: P(X>x) = 1 - P(X<=x)
printDistributions(x, Px, Rx, "Hypergeometric")
# Out:
# Probability success in one attempt = 0.4
# ************* Hypergeometric PROBABILITY DISTRIBUTIONS *************
#    x      P(x)      R(x)
# 0  0  0.023839  0.976161
# 1  1  0.163467  0.812693
# 2  2  0.357585  0.455108
# 3  3  0.317853  0.137255
# 4  4  0.119195  0.018060
# 5  5  0.017337  0.000722
# 6  6  0.000722  0.000000

# %%
#Poisson
from scipy.stats import poisson
myLambda= 1.2 #taxa de ocorrências por unidade de medida (mu in Python)
x = list(range(0,21))#
dist = poisson(mu = myLambda)#Omega_X = {0, 1, ...}
Px = dist.pmf(x)#probability mass function: P(X=x)
Rx = dist.sf(x)#Reliability/Survival function: P(X>x) = 1 - P(X<=x)
printDistributions(x, Px, Rx, "Poisson")
# Out:
# ************* Poisson PROBABILITY DISTRIBUTIONS *************
#      x          P(x)          R(x)
# 0    0  3.011942e-01  6.988058e-01
# 1    1  3.614331e-01  3.373727e-01
# 2    2  2.168598e-01  1.205129e-01
# 3    3  8.674393e-02  3.376897e-02
# 4    4  2.602318e-02  7.745788e-03
# 5    5  6.245563e-03  1.500225e-03
# 6    6  1.249113e-03  2.511125e-04
# 7    7  2.141336e-04  3.697887e-05
# 8    8  3.212004e-05  4.858829e-06
# 9    9  4.282672e-06  5.761568e-07
# 10  10  5.139206e-07  6.223618e-08
# 11  11  5.606407e-08  6.172115e-09
# 12  12  5.606407e-09  5.657078e-10
# 13  13  5.175145e-10  4.819333e-11
# 14  14  4.435838e-11  3.834945e-12
# 15  15  3.548671e-12  2.862740e-13
# 16  16  2.661503e-13  2.012369e-14
# 17  17  1.878708e-14  1.336609e-15
# 18  18  1.252472e-15  8.413652e-17
# 19  19  7.910350e-17  5.033027e-18
# 20  20  4.746210e-18  2.868177e-19

# %%
#Mistura entre Poisson e Binomial ...
from scipy.stats import poisson
from scipy.stats import binom
#Y: nº de novos casos de Covid-19 por dia em dado local
#Y~Poisson(lambda=1.2)
Y_dist = poisson(mu = 1.2)#Omega_Y = {0, 1, ...}
pY_greaterOrEqualTo3 = Y_dist.sf(2)#P(Y>=3) = P(Y>2)
print("P(Y>=3) = ", pY_greaterOrEqualTo3)
n=10
#X: nº de locais em que ocorre ao menos 3 casos de Covid-19 por dia, de uma
#amostra de (n=)10 locais
#X~binomial(n=10, p=P(Y>=3))
x = list(range(0, n+1))
X_dist = binom(n, pY_greaterOrEqualTo3)
Px = X_dist.pmf(x)#probability mass function: P(X=x)
Rx = X_dist.sf(x)#Reliability/Survival function: P(X>x) = 1 - P(X<=x)
printDistributions(x, Px, Rx, "Poisson-based Binomial")
# Out:
# P(Y>=3) =  0.12051290121636986
# ************* Poisson-based Binomial PROBABILITY DISTRIBUTIONS *************
#      x          P(x)          R(x)
# 0    0  2.768820e-01  7.231180e-01
# 1    1  3.794013e-01  3.437167e-01
# 2    2  2.339459e-01  1.097708e-01
# 3    3  8.548466e-02  2.428618e-02
# 4    4  2.049889e-02  3.787291e-03
# 5    5  3.370665e-03  4.166253e-04
# 6    6  3.848916e-04  3.173371e-05
# 7    7  3.013731e-05  1.596403e-06
# 8    8  1.548602e-06  4.780154e-08
# 9    9  4.715539e-08  6.461531e-10
# 10  10  6.461531e-10  0.000000e+00
